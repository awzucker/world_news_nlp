# %% [markdown]
# # World News NLP Project: Notebook 1
# ## Data Imports, Cleaning & EDA
# #### Adam Zucker
#
# ---

# %% [markdown]
# ## Problem
#
# Statement
#
# ---

# %% [markdown]
# ## Notebook Contents
#
# Imports, cleaning, EDA, basic background...
#
# ---

# %% [markdown]
# ## Data
#
# Data Dict?
#
# ---

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import spacy
from spacy import displacy

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from nltk.tokenize import RegexpTokenizer
from nltk.sentiment.vader import SentimentIntensityAnalyzer

from geotext import GeoText

import time
from datetime import datetime

# %%
# Reading in data
df = pd.read_csv('../data/world_news_posts.csv')

# %%
df.head()
# Out:
#    time_created date_created  up_votes  down_votes  \
# 0    1201232046   2008-01-25         3           0
# 1    1201232075   2008-01-25         2           0
# 2    1201232523   2008-01-25         3           0
# 3    1201233290   2008-01-25         1           0
# 4    1201274720   2008-01-25         4           0
#
#                                              title  over_18    author  \
# 0                Scores killed in Pakistan clashes    False     polar
# 1                 Japan resumes refuelling mission    False     polar
# 2                  US presses Egypt on Gaza border    False     polar
# 3     Jump-start economy: Give health care to all     False   fadi420
# 4  Council of Europe bashes EU&UN terror blacklist    False  mhermans
#
#     category
# 0  worldnews
# 1  worldnews
# 2  worldnews
# 3  worldnews
# 4  worldnews

# %% [markdown]
# ---

# %% [markdown]
# ## EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 509236 entries, 0 to 509235
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   time_created  509236 non-null  int64
#  1   date_created  509236 non-null  object
#  2   up_votes      509236 non-null  int64
#  3   down_votes    509236 non-null  int64
#  4   title         509236 non-null  object
#  5   over_18       509236 non-null  bool
#  6   author        509236 non-null  object
#  7   category      509236 non-null  object
# dtypes: bool(1), int64(3), object(4)
# memory usage: 27.7+ MB

# %%
# Checking for nulls in the dataframe - none detected
df.isnull().sum()
# Out:
# time_created    0
# date_created    0
# up_votes        0
# down_votes      0
# title           0
# over_18         0
# author          0
# category        0
# dtype: int64

# %%
# Defining a function to concisely process this dataframe and others in the same format
def process_data(df):
    
    # Redefining the 'time_created' column to hold datetime, converted from unix timestamp format
    df['time_created'] = [datetime.fromtimestamp(ts) for ts in df['time_created']]
    # Dropping 'date_created' because of redundancy
    df.drop(columns='date_created', inplace=True)
    
    # Creating a feature to hold the post length in characters
    df['post_length_chars'] = df['title'].apply(len)
    
    # Generating features for total number of posts by author and total number of upvotes by author
    df['author_upvotes'] = 
    df['author_posts'] = 
    
    # Generating a feature to hold day of the week and dummifying
    df['weekday'] = df['time_created'].dt.day_name()
    day_dummies = pd.get_dummies(df['weekday'], drop_first=True)
    df = pd.concat([df, day_dummies], axis=1)
    df.drop('weekday', inplace=True)
    
    # Dropping 'category' feature if only one category is present
    if len(df['category'].unique()) == 1:
        df.drop(columns='category', inplace=True)
    # Similarly dropping down votes if there are none reported
    if sum(df['down_votes']) == 0:
        df.drop(columns='down_votes', inplace=True)
    
    # Binarizing 'over_18' feature
    df['over_18'] = df['over_18'].map({False:0, True:1})
    
    # Reordering columns for clarity
    # df = df[['author', 'title', 'up_votes', 'over_18', 'post_length_chars' 'time_created', 
    #          'weekday', 'Saturday', 'Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday']]
    
    return df

# %%
process_data(df)
# Out:
#               time_created  up_votes  \
# 0      2008-01-24 22:34:06         3
# 1      2008-01-24 22:34:35         2
# 2      2008-01-24 22:42:03         3
# 3      2008-01-24 22:54:50         1
# 4      2008-01-25 10:25:20         4
# ...                    ...       ...
# 509231 2016-11-22 07:12:44         5
# 509232 2016-11-22 07:12:52         1
# 509233 2016-11-22 07:17:36         1
# 509234 2016-11-22 07:19:17         1
# 509235 2016-11-22 07:22:26         1
#
#                                                     title  over_18  \
# 0                       Scores killed in Pakistan clashes        0
# 1                        Japan resumes refuelling mission        0
# 2                         US presses Egypt on Gaza border        0
# 3            Jump-start economy: Give health care to all         0
# 4         Council of Europe bashes EU&UN terror blacklist        0
# ...                                                   ...      ...
# 509231   Heil Trump : Donald Trump s  alt-right  white...        0
# 509232  There are people speculating that this could b...        0
# 509233          Professor receives Arab Researchers Award        0
# 509234  Nigel Farage attacks response to Trump ambassa...        0
# 509235  Palestinian wielding knife shot dead in West B...        0
#
#                author  post_length_chars   weekday  Monday  Saturday  Sunday  \
# 0               polar                 33  Thursday       0         0       0
# 1               polar                 32  Thursday       0         0       0
# 2               polar                 31  Thursday       0         0       0
# 3             fadi420                 44  Thursday       0         0       0
# 4            mhermans                 47    Friday       0         0       0
# ...               ...                ...       ...     ...       ...     ...
# 509231  nonamenoglory                 88   Tuesday       0         0       0
# 509232      SummerRay                 67   Tuesday       0         0       0
# 509233      AUSharjah                 41   Tuesday       0         0       0
# 509234    smilyflower                 55   Tuesday       0         0       0
# 509235     superislam                 64   Tuesday       0         0       0
#
#         Thursday  Tuesday  Wednesday
# 0              1        0          0
# 1              1        0          0
# 2              1        0          0
# 3              1        0          0
# 4              0        0          0
# ...          ...      ...        ...
# 509231         0        1          0
# 509232         0        1          0
# 509233         0        1          0
# 509234         0        1          0
# 509235         0        1          0
#
# [509236 rows x 13 columns]

# %%
# Converting 'date_created' to datetime
df['date_created'] = pd.to_datetime(df['date_created'])

# %%
df.dtypes
# Out:
# time_created             int64
# date_created    datetime64[ns]
# up_votes                 int64
# down_votes               int64
# title                   object
# over_18                   bool
# author                  object
# category                object
# dtype: object

# %%
# The data spans 3223 days, from 1/25/08 to 11/22/16
print(f"Number of days represented in dataframe: {len(df['date_created'].unique())}")
print(f"Data date range is from {min(df['date_created'])} to {max(df['date_created'])}")
# Out:
# Number of days represented in dataframe: 3223
# Data date range is from 2008-01-25 00:00:00 to 2016-11-22 00:00:00

# %%
# All posts are classified as 'worldnews' - with just a single class represented, this feature becomes unnecessary
df['category'].value_counts()
# Out:
# worldnews    509236
# Name: category, dtype: int64

# %%
# Dropping 'category' feature
df.drop(columns='category', inplace=True)

# %% [markdown]
# ---

# %%
# Summary stats for upvotes
df['up_votes'].describe()
# Out:
# count    509236.000000
# mean        112.236283
# std         541.694675
# min           0.000000
# 25%           1.000000
# 50%           5.000000
# 75%          16.000000
# max       21253.000000
# Name: up_votes, dtype: float64

# %%
# Looking at titles of most upvoted posts
df['up_votes'].groupby(df['title']).sum().sort_values(ascending=False)[0:50].to_frame()
# Out:
#                                                     up_votes
# title
# A biotech startup has managed to 3-D print fake...     21253
# 455100  Pacific Bluefin Tuna: Population Drops 97% Due...    False
# 389637  Legal scholars warn against 10 year prison for...    False
# 399885  NASA announces discovery of flowing water in Mars    False
# 391218  Thousands of prehistoric mammoth tusks are bei...    False
# 447086  US State Dept declares ISIS is committing geno...    False
# 352692  German anti-vaccer wagers € 100,000 to anyone ...    False
# 494498  Indian Prime Minister:  I want to tell the peo...    False
# 377893  Alberta passes bill banning corporate and unio...    False
# 391608  The first UN privacy chief has said the world ...    False
# 422985  Just miles from the US border, Lexmark fires 9...    False
# 390157  Afghan military interpreter who served with Br...    False
# 453393  Saudi Arabia strips religious police of arrest...    False
# 427153  Microsoft Corp said on Wednesday it will begin...    False
# 431972  The solar system appears to have a new ninth p...    False
# 447933  Netherlands will once again need to close pris...    False
# 451782  David Cameron personally intervened to prevent...    False
# 467944  U.N. Chief Admits He Removed Saudi Arabia From...    False
# 503340  The South Korean President has been under the ...    False
# 454072  Saudi Arabia has told the Obama administration...    False
# 420414  German Vice Chancellor Gabriel: Saudi Arabia m...    False
# 464003  Adidas shoe manufacture returns to Germany, fu...    False
#
#                       author
# 377200             KRISHNA53
# 391415         joeyoungblood
# 450818          mister_geaux
# 391318      navysealassulter
# 390252             seapiglet
# 449809                Xiroth
# 397215         DoremusJessup
# 390494         DawgsOnTopUGA
# 500786                  mvea
# 388230               fiffers
# 465396   Flamo_the_Idiot_Boy
# 495329             tiribazus
# 447311              Wagamaga
# 187603           dantesinfer
# 389011             damsteegt
# 412603               emr1028
# 354925               pnewell
# 387922           Noticemenot
# 437930          Andromeda321
# 494404             MarcoshLA
# 480475         bimonscificon
# 389068    haunted_cheesecake
# 389806       AmerikanInfidel
# 446779               jurvand
# 489733                madam1
# 326108       Herman999999999
# 505849    Short_Term_Account
# 358243              DrSalted
# 488435              briancon
# 455100               Vippero
# 389637           Noticemenot
# 399885            ProfGiallo
# 391218      EightRoundsRapid
# 447086       guiltyofnothing
# 352692   bendertheoffender22
# 494498            iconoclaus
# 377893         awake-at-dawn
# 391608              Wagamaga
# 422985                 jb492
# 390157         crippledrejex
# 453393              Salman91
# 427153            Samjones31
# 431972       NinjaDiscoJesus
# 447933             xlnqeniuz
# 451782               StoCazz
# 467944            terran1212
# 503340           FlandersNed
# 454072  acupoftwodayoldcoffe
# 420414               Ebshoun
# 464003            JarkAttack

# %%
df['down_votes'].value_counts()
# Out:
# 0    509236
# Name: down_votes, dtype: int64

# %%
# No downvotes in dataframe, so this feature can be dropped
df.drop(columns='down_votes', inplace=True)

# %%
df.head()
# Out:
#    time_created date_created  up_votes  \
# 0    1201232046   2008-01-25         3
# 1    1201232075   2008-01-25         2
# 2    1201232523   2008-01-25         3
# 3    1201233290   2008-01-25         1
# 4    1201274720   2008-01-25         4
#
#                                              title  over_18    author
# 0                Scores killed in Pakistan clashes    False     polar
# 1                 Japan resumes refuelling mission    False     polar
# 2                  US presses Egypt on Gaza border    False     polar
# 3     Jump-start economy: Give health care to all     False   fadi420
# 4  Council of Europe bashes EU&UN terror blacklist    False  mhermans

# %% [markdown]
# ---

# %%
print(f"Number of unique authors: {len(df['author'].unique())}")
print('-----')
print(f"Top 20 contributors by post count: \n{df['author'].value_counts()[0:20]}")
print('-----')
print(f"Top 20 contributors by upvotes: \n{df['up_votes'].groupby(df['author']).sum().sort_values(ascending=False)[0:20]}")
# Out:
# Number of unique authors: 85838
# -----
# Top 20 contributors by post count:
# davidreiss666         8897
# anutensil             5730
# DoremusJessup         5037
# maxwellhill           4023
# igeldard              4013
# readerseven           3170
# twolf1                2923
# madam1                2658
# nimobo                2564
# madazzahatter         2503
# ionised               2493
# NinjaDiscoJesus       2448
# bridgesfreezefirst    2405
# SolInvictus           2181
# Libertatea            2108
# vigorous              2077
# galt1776              1897
# DougBolivar           1770
# bob21doh              1698
# trot-trot             1649
# Name: author, dtype: int64
# -----
# Top 20 contributors by upvotes:
# author
# maxwellhill         1985416
# anutensil           1531544
# Libertatea           832102
# DoremusJessup        584380
# Wagamaga             580121
# NinjaDiscoJesus      492582
# madazzahatter        428966
# madam1               390541
# davidreiss666        338306
# kulkke               333311
# pnewell              297270
# nimobo               266733
# trot-trot            258367
# ionised              256159
# EightRoundsRapid     254670
# twolf1               230031
# mepper               223369
# PanAfrica            219742
# readerseven          209225
# green_flash          205554
# Name: up_votes, dtype: int64

# %% [markdown]
# ---

# %%
# Looking at distribution of 'over_18' posts by number and percentage
print(df['over_18'].value_counts())
print(df['over_18'].value_counts(normalize=True))
# Out:
# False    508916
# True        320
# Name: over_18, dtype: int64
# False    0.999372
# True     0.000628
# Name: over_18, dtype: float64

# %%
# Checking title content of some of the posts classified as "over_18"
df[df['over_18'] == True]
# Out:
#         time_created date_created  up_votes  \
# 1885      1206381438   2008-03-24       189
# 6721      1211138718   2008-05-18         5
# 8414      1212694925   2008-06-05         0
# 12163     1216672016   2008-07-21         0
# 12699     1217381380   2008-07-30         5
# ...              ...          ...       ...
# 503776    1477889966   2016-10-31         4
# 508067    1479400229   2016-11-17        12
# 508176    1479434681   2016-11-18         0
# 508376    1479492875   2016-11-18         6
# 508706    1479641575   2016-11-20         0
#
#                                                     title  over_18  \
# 1885    Pics from the Tibetan protests - more graphic ...     True
# 6721    MI5 linked to Max Mosley’s Nazi-style, sadomas...     True
# 8414    Tabloid Horrifies Germany: Poland s Yellow Pre...     True
# 12163   Love Parade Dortmund: Techno Festival Breaks R...     True
# 12699   IDF kills young Palestinian boy. Potentially N...     True
# ...                                                   ...      ...
# 503776  Latest Italian Earthquake Devastates Medieval ...     True
# 508067  ISIS Release Video Showing Melbourne As A Poss...     True
# 508176  Animal welfare activists have released footage...     True
# 508376   Jungle Justice : Public lynching of a street ...     True
# 508706  [NSFW] Teenage boy run over by  Iraqi army tan...     True
#
#                  author
# 1885            pressed
# 6721             alllie
# 8414             stesch
# 12163            stesch
# 12699               cup
# ...                 ...
# 503776       pixelinthe
# 508067         halacska
# 508176  NinjaDiscoJesus
# 508376           avivi_
# 508706           atyzer
#
# [320 rows x 6 columns]

# %%
nsfw = df[df['over_18'] == True]
nsfw.sort_values(by='up_votes', ascending=False)[0:25]
# Out:
#         time_created date_created  up_votes  \
# 500590    1476806936   2016-10-18      7941
# 494536    1474805114   2016-09-25      6322
# 428689    1452167289   2016-01-07      5878
# 462067    1463480226   2016-05-17      5617
# 303900    1409942733   2014-09-05      5507
# 461255    1463150094   2016-05-13      4839
# 376435    1434501068   2015-06-17      4209
# 269963    1398120460   2014-04-21      3831
# 431221    1453095585   2016-01-18      3823
# 246618    1390489347   2014-01-23      3738
# 246638    1390494386   2014-01-23      3464
# 238610    1387702158   2013-12-22      3457
# 195725    1373253713   2013-07-08      3301
# 157591    1359652841   2013-01-31      2689
# 206634    1377136004   2013-08-22      2569
# 37176     1245520828   2009-06-20      2547
# 426859    1451431228   2015-12-29      2532
# 185486    1369894739   2013-05-30      2362
# 122902    1337270498   2012-05-17      2351
# 248524    1391033376   2014-01-29      1918
# 137501    1348244038   2012-09-21      1905
# 361295    1429163593   2015-04-16      1903
# 200886    1374891708   2013-07-27      1873
# 494947    1474967159   2016-09-27      1855
# 109678    1325210152   2011-12-30      1854
#
#                                                     title  over_18  \
# 500590  Judge presiding over  El Chapo s  case shot, k...     True
# 494536  [NSFL] Australian child molester Peter Scully ...     True
# 428689  Armed suspect shot dead after trying to storm ...     True
# 462067  Syria Army killed over 200 ISIS militants in 3...     True
# 303900                         Man escapes ISIS execution     True
# 461255  ISIS massacre 14 Real Madrid fans at supporter...     True
# 376435  The fight is on to stop an annual Chinese even...     True
# 269963  China: “Violent Government Thugs” Beaten To De...     True
# 431221  ISIS commits largest massacre since Syrian con...     True
# 246618  Video of riot police stripping detained protes...     True
# 246638  Ukraine: Police undress arrested to take group...     True
# 238610   Kill Gays  bill just passed in Uganda - presi...     True
# 195725  Mexico: Teenager stabbed to death for recordin...     True
# 157591  Recent pictures from war-ridden Damascus by Re...     True
# 206634  Hundreds of children s bodies piled high after...     True
# 37176    Woman killed in protests (Iran) *shocking, nsfw.     True
# 426859  ISIS militants burn 20 media activists to deat...     True
# 185486  First topless protest in an Islamic state lead...     True
# 122902          Mexico s Drug War: 50,000 Dead in 6 Years     True
# 248524  Photos of Ukrainian uprising. Includes a dude ...     True
# 137501   Muslim, let s get naked : Ukraine-based activ...     True
# 361295  A 250-year-old leather dildo has been discover...     True
# 200886  Soldiers’ Mass Execution Reported by Syria Gro...     True
# 494947  Paris to create designated space for naked peo...     True
# 109678       Mexican Drug War - Five Years Later (images)     True
#
#                      author
# 500590             IsleCook
# 494536            ExWhySaid
# 428689             rawmas02
# 462067     orangeflower2015
# 303900             brothamo
# 461255             PeterG92
# 376435        ShakoWasAngry
# 269963       helpmesleep666
# 431221            AllenDono
# 246618             _skylark
# 246638             uncleban
# 238610           Lulubelle_
# 195725               skorda
# 157591         moses_herzog
# 206634          Sociomancer
# 37176             cactusrex
# 426859               dvzhou
# 185486            goliathrk
# 122902               mepper
# 248524      UlyssesOntusado
# 137501         KatieMorosky
# 361295       EndOfRedditors
# 200886       uptodatepronto
# 494947              n0k1man
# 109678  puedo_tener_chzbrgr

# %% [markdown]
# ---

# %% [markdown]
# ## Feature Engineering

# %%
df['post_length'] = ''
c=0
for t in df['title']:
    df['post_length'][c] = len(t)
    c+=1
# Out:
# <ipython-input-26-d78e1070b655>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['post_length'][c] = len(t)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-d78e1070b655> in <module>
#       2 c=0
#       3 for t in df['title']:
# ----> 4     df['post_length'][c] = len(t)
#       5     c+=1
#
# ~/opt/anaconda3/envs/dsi/lib/python3.8/site-packages/pandas/core/series.py in __setitem__(self, key, value)
#    1027
#    1028         if cacher_needs_updating:
# -> 1029             self._maybe_update_cacher()
#    1030
#    1031     def _set_with_engine(self, key, value):
#
# ~/opt/anaconda3/envs/dsi/lib/python3.8/site-packages/pandas/core/generic.py in _maybe_update_cacher(self, clear, verify_is_copy)
#    3236                 if len(self) == len(ref):
#    3237                     # otherwise, either self or ref has swapped in new arrays
# -> 3238                     ref._maybe_cache_changed(cacher[0], self)
#    3239                 else:
#    3240                     # GH#33675 we have swapped in a new array, so parent
#
# ~/opt/anaconda3/envs/dsi/lib/python3.8/site-packages/pandas/core/generic.py in _maybe_cache_changed(self, item, value)
#    3197         """
#    3198         loc = self._info_axis.get_loc(item)
# -> 3199         self._mgr.iset(loc, value)
#    3200
#    3201     @property
#
# ~/opt/anaconda3/envs/dsi/lib/python3.8/site-packages/pandas/core/internals/managers.py in iset(self, loc, value)
#    1094             blk_locs = blklocs[val_locs.indexer]
#    1095             if blk.should_store(value):
# -> 1096                 blk.set(blk_locs, value_getitem(val_locs))
#    1097             else:
#    1098                 unfit_mgr_locs.append(blk.mgr_locs.as_array[blk_locs])
#
# ~/opt/anaconda3/envs/dsi/lib/python3.8/site-packages/pandas/core/internals/blocks.py in set(self, locs, values)
#     329         create a new array and always creates a new Block.
#     330         """
# --> 331         self.values[locs] = values
#     332
#     333     def delete(self, loc) -> None:
#
# KeyboardInterrupt:

# %%
df['post_length_chars'] = df['title'].apply(len)

# %%
df
# Out:
#         time_created date_created  up_votes  \
# 0         1201232046   2008-01-25         3
# 1         1201232075   2008-01-25         2
# 2         1201232523   2008-01-25         3
# 3         1201233290   2008-01-25         1
# 4         1201274720   2008-01-25         4
# ...              ...          ...       ...
# 509231    1479816764   2016-11-22         5
# 509232    1479816772   2016-11-22         1
# 509233    1479817056   2016-11-22         1
# 509234    1479817157   2016-11-22         1
# 509235    1479817346   2016-11-22         1
#
#                                                     title  over_18  \
# 0                       Scores killed in Pakistan clashes    False
# 1                        Japan resumes refuelling mission    False
# 2                         US presses Egypt on Gaza border    False
# 3            Jump-start economy: Give health care to all     False
# 4         Council of Europe bashes EU&UN terror blacklist    False
# ...                                                   ...      ...
# 509231   Heil Trump : Donald Trump s  alt-right  white...    False
# 509232  There are people speculating that this could b...    False
# 509233          Professor receives Arab Researchers Award    False
# 509234  Nigel Farage attacks response to Trump ambassa...    False
# 509235  Palestinian wielding knife shot dead in West B...    False
#
#                author post_length  post_length_chars
# 0               polar          33                 33
# 1               polar          32                 32
# 2               polar          31                 31
# 3             fadi420          44                 44
# 4            mhermans          47                 47
# ...               ...         ...                ...
# 509231  nonamenoglory                             88
# 509232      SummerRay                             67
# 509233      AUSharjah                             41
# 509234    smilyflower                             55
# 509235     superislam                             64
#
# [509236 rows x 8 columns]

# %% [markdown]
# ---

# %% [markdown]
# ## Data Visualizations
